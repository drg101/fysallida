# %% [markdown]
# # Import data

# %%
# !pip install smogn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: smogn in /home/drg101/.local/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: numpy in /home/drg101/.local/lib/python3.9/site-packages (from smogn) (1.22.1)
# Requirement already satisfied: tqdm in /home/drg101/.local/lib/python3.9/site-packages (from smogn) (4.64.0)
# Requirement already satisfied: pandas in /home/drg101/.local/lib/python3.9/site-packages (from smogn) (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in /home/drg101/.local/lib/python3.9/site-packages (from pandas->smogn) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/drg101/.local/lib/python3.9/site-packages (from pandas->smogn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/drg101/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->smogn) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.preprocessing import normalize, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
#import smogn


data_df = pd.read_csv('../data/old.csv')
pred_df = pd.read_csv('../data/crash_amounts.csv')

labels = list(data_df)[3:]
print(labels)

new_data_df = []

X = []
for index, row in pred_df.iterrows():
    relevant_x = data_df.loc[data_df["GISJOIN"] == row["GISJOIN"]]
    new_data_df.append([*relevant_x.values.flatten().tolist(),row['crash_amount']])
    X.append(relevant_x[labels].to_numpy().reshape(-1))
    

    
X = np.array(X)
min_max_scaler = MinMaxScaler()
min_max_scaler.fit(X)
X = min_max_scaler.transform(X)
T = pred_df[["crash_amount"]].to_numpy()

new_data_df = pd.DataFrame(new_data_df, columns=[*list(data_df), 'crash_amount'])
# Out:
# ['bachelors_degree', 'gini_index', 'median_household_income', 'median_age', 'white', 'black', 'native_american', 'asian', 'poverty', 'owned', 'occupied', 'avg_annual_pay', 'oty_annual_avg_estabs_pct_chg', 'oty_annual_avg_emplvl_pct_chg', 'oty_total_annual_wages_pct_chg', 'oty_taxable_annual_wages_pct_chg', 'oty_annual_contributions_pct_chg', 'oty_annual_avg_wkly_wage_pct_chg', 'oty_avg_annual_pay_pct_chg']

# %%
data_df
# Out:
#        GISJOIN              county_name   total     bachelors_degree  \
# 0     G4800630              Camp County   12489   0.1550012725884449
# 1     G4801470            Fannin County   32884   0.1341053748231966
# 2     G2201210  West Baton Rouge Parish   22323  0.16908346631513219
# 3     G2600050           Allegan County  112817  0.19706893285339253
# 4     G5500890           Ozaukee County   85554   0.4220551553315076
# ...        ...                      ...     ...                  ...
# 3411  G0800530          Hinsdale County     554   0.2066326530612245
# 3412  G4200150          Bradford County   61375  0.15578187688436246
# 3413  G3900390          Defiance County   38516  0.15081723625557206
# 3414  G5500410            Forest County    9764  0.11020589542290031
# 3415  G2500070             Dukes County   15675   0.4007326661901358
#
#      gini_index median_household_income median_age               white  \
# 0         0.448                44736.12       36.5  0.7938986307950997
# 1         0.414                55998.36       39.9  0.8754409439240968
# 2         0.428      61360.200000000004       35.2   0.610088249787215
# 3         0.397                68419.56       37.7  0.9215011921962115
# 4         0.448       97992.84000000001       42.3  0.9559225752156533
# ...         ...                     ...        ...                 ...
# 3411      0.414                   70950       34.2  0.9494584837545126
# 3412       0.42                51799.44       42.4  0.9750386965376782
# 3413      0.398      59504.280000000006         39  0.9388825423200747
# 3414      0.432                   48081       43.6  0.8383859074149939
# 3415      0.458       82463.04000000001       44.4  0.8699840510366826
#
#                       black        native_american  ...               owned  \
# 0       0.16718712466970934  0.0023220433981904075  ...  0.6458616010854816
# 1       0.07511251672545918  0.0063860844179540206  ...  0.7293723554301833
# 2        0.3493258074631546   0.001478295927966671  ...  0.7425845021844102
# 3      0.013322460267512874   0.004458547913878228  ...  0.8355387072932313
# 4      0.013734015943147018  0.0014844425742805713  ...  0.7865398900609122
# ...                     ...                    ...  ...                 ...
# 3411                      0   0.036101083032490974  ...  0.6666666666666666
# 3412  0.0057841140529531565  0.0024928716904276988  ...  0.7450268329096558
# 3413   0.015526015162529858   0.004855125142797798  ...  0.7865395913571382
# 3414   0.016591560835723065    0.11675542810323637  ...  0.7441914498141264
# 3415    0.03712918660287081   0.019521531100478468  ...  0.7970473141230878
#
#                  occupied      avg_annual_pay oty_annual_avg_estabs_pct_chg  \
# 0      0.8122703894195444   6866.301094890511            11.716240875912407
# 1      0.8324038743762842   7599.346381969158            16.209134045077114
# 2      0.9211055808535423   9369.228473019517             6.441791044776122
# 3      0.8671104587459428  12128.511940298507             4.119776119402983
# 4      0.9451527746573803  15975.303052866717             5.643782576321666
# ...                   ...                 ...                           ...
# 3411  0.12745098039215685   4325.923076923077             8.381623931623931
# 3412   0.8410996097064314   9046.103574702109             7.542163153070586
# 3413   0.9070400852625969  10278.242331288344             7.270961145194272
# 3414  0.48408502980542123    6204.43736730361            1.8004246284501062
# 3415  0.35012767017500157  13615.658986175114             5.300691244239627
#
#      oty_annual_avg_emplvl_pct_chg oty_total_annual_wages_pct_chg  \
# 0               0.7213503649635036              1.113321167883212
# 1              -0.5359430604982202             1.4930011862396197
# 2               0.9362801377726744               2.21825487944891
# 3                0.618134328358208             2.0975373134328335
# 4               1.0655994043186892             2.1597170513775112
# ...                            ...                            ...
# 3411           -0.4871794871794872             0.2658119658119658
# 3412            1.1168652612282308             3.6206232813932195
# 3413            0.6972392638036808             2.4072597137014324
# 3414          -0.11847133757961764            0.23545647558386423
# 3415            1.9058755760368675             3.2985023041474646
#
#      oty_taxable_annual_wages_pct_chg oty_annual_contributions_pct_chg  \
# 0                -0.02427007299270081              -2.7644160583941595
# 1                  1.9160142348754459               0.6404507710557529
# 2                  0.8267508610792187                 0.91894374282434
# 3                   0.852910447761194               2.5017910447761182
# 4                  1.2202531645569616               0.6797468354430368
# ...                               ...                              ...
# 3411                0.666666666666667              -1.2623931623931628
# 3412               0.7186067827681026              -0.3649862511457384
# 3413                1.621676891615543               1.7088957055214729
# 3414              0.17133757961783433               0.5036093418259017
# 3415               1.7263824884792631               2.4010368663594486
#
#      oty_annual_avg_wkly_wage_pct_chg oty_avg_annual_pay_pct_chg
# 0                 0.49562043795620464        0.49689781021897794
# 1                   1.728469750889681         1.7256227758007134
# 2                  1.0195177956371988          1.021125143513203
# 3                   1.556492537313432          1.560597014925373
# 4                  1.0529411764705887          1.054728220402084
# ...                               ...                        ...
# 3411               1.6141025641025635         1.6029914529914524
# 3412                1.160219981668193         1.1621448212648933
# 3413               1.1328220858895717         1.1303680981595094
# 3414               0.5055201698513796         0.4989384288747341
# 3415               1.6505760368663598          1.648617511520737
#
# [3416 rows x 22 columns]

# %%
pred_df.sort_values(by='crash_amount', ascending=False)
# Out:
#      Unnamed: 0              county   GISJOIN  highest_price  lowest_price  \
# 229         229       Merced County  G0600470       373376.0      111317.0
# 14           14        Wayne County  G2601630       157238.0       48176.0
# 118         118   Stanislaus County  G0600990       425152.0      140078.0
# 228         228      Clayton County  G1300630       130244.0       45161.0
# 80           80  San Joaquin County  G0600770       460671.0      162641.0
# ..          ...                 ...       ...            ...           ...
# 343         343     Ouachita Parish  G2200730       123592.0      119586.0
# 661         661       Holmes County  G3900750       138185.0      133889.0
# 671         671        Tioga County  G4201170       108619.0      105557.0
# 871         871     Saunders County  G3101550       148062.0      145762.0
# 768         768     Van Wert County  G3901610        74742.0       73897.0
#
#      crash_amount
# 229      0.701864
# 14       0.693611
# 118      0.670523
# 228      0.653258
# 80       0.646948
# ..            ...
# 343      0.032413
# 661      0.031089
# 671      0.028190
# 871      0.015534
# 768      0.011306
#
# [1066 rows x 6 columns]

# %%
X.shape, T.shape
# Out:
# ((1066, 19), (1066, 1))

# %%
X_train, X_test, T_train, T_test = train_test_split(X,T,test_size=0.3)
X_train.shape, X_test.shape, T_train.shape, T_test.shape
# Out:
# ((746, 19), (320, 19), (746, 1), (320, 1))

# %% [markdown]
# # Correlations

# %%
corr_thing = pd.DataFrame(list(np.hstack((T.reshape(-1,1),X))), columns=["target",*labels])
corr_thing.corr()
# Out:
#                                     target  bachelors_degree  gini_index  \
# target                            1.000000          0.102033    0.011995
# bachelors_degree                  0.102033          1.000000    0.122554
# gini_index                        0.011995          0.122554    1.000000
# median_household_income           0.204317          0.765688   -0.339850
# median_age                       -0.050589         -0.192640   -0.048695
# white                            -0.211397         -0.015036   -0.399567
# black                             0.064692         -0.129906    0.387136
# native_american                   0.020948         -0.090011   -0.006722
# asian                             0.216522          0.499943    0.068336
# poverty                          -0.104923         -0.560311    0.524108
# owned                            -0.069584         -0.213299   -0.500854
# occupied                         -0.030849          0.259046   -0.176396
# avg_annual_pay                    0.315393          0.734697    0.230965
# oty_annual_avg_estabs_pct_chg     0.258652          0.180920   -0.039679
# oty_annual_avg_emplvl_pct_chg     0.226192          0.350610    0.068833
# oty_total_annual_wages_pct_chg    0.019612         -0.027709   -0.049542
# oty_taxable_annual_wages_pct_chg  0.161088          0.323984    0.061314
# oty_annual_contributions_pct_chg  0.034840          0.029450    0.033912
# oty_annual_avg_wkly_wage_pct_chg  0.136636          0.332476    0.109845
# oty_avg_annual_pay_pct_chg        0.137004          0.333453    0.110247
#
#                                   median_household_income  median_age  \
# target                                           0.204317   -0.050589
# bachelors_degree                                 0.765688   -0.192640
# gini_index                                      -0.339850   -0.048695
# median_household_income                          1.000000   -0.106038
# median_age                                      -0.106038    1.000000
# white                                            0.119860    0.363078
# black                                           -0.275016   -0.213022
# native_american                                 -0.105108   -0.037575
# asian                                            0.487920   -0.229219
# poverty                                         -0.823738   -0.154721
# owned                                            0.157731    0.518069
# occupied                                         0.366485   -0.435612
# avg_annual_pay                                   0.594860   -0.251313
# oty_annual_avg_estabs_pct_chg                    0.227542   -0.137195
# oty_annual_avg_emplvl_pct_chg                    0.305074   -0.204404
# oty_total_annual_wages_pct_chg                   0.019408   -0.013681
# oty_taxable_annual_wages_pct_chg                 0.284913   -0.170968
# oty_annual_contributions_pct_chg                 0.052690   -0.037600
# oty_annual_avg_wkly_wage_pct_chg                 0.238399   -0.172279
# oty_avg_annual_pay_pct_chg                       0.239099   -0.172526
#
#                                      white     black  native_american  \
# target                           -0.211397  0.064692         0.020948
# bachelors_degree                 -0.015036 -0.129906        -0.090011
# gini_index                       -0.399567  0.387136        -0.006722
# median_household_income           0.119860 -0.275016        -0.105108
# median_age                        0.363078 -0.213022        -0.037575
# white                             1.000000 -0.866700        -0.113131
# black                            -0.866700  1.000000        -0.123173
# native_american                  -0.113131 -0.123173         1.000000
# asian                            -0.312414 -0.047877        -0.027763
# poverty                          -0.416659  0.476322         0.119649
# owned                             0.533854 -0.363955        -0.009947
# occupied                         -0.026406 -0.045915        -0.120978
# avg_annual_pay                   -0.210107 -0.008918        -0.089292
# oty_annual_avg_estabs_pct_chg    -0.061287 -0.073566         0.084328
# oty_annual_avg_emplvl_pct_chg    -0.137719 -0.045334         0.040492
# oty_total_annual_wages_pct_chg   -0.020908  0.027787        -0.005250
# oty_taxable_annual_wages_pct_chg -0.112502 -0.039552         0.005013
# oty_annual_contributions_pct_chg -0.033815  0.015284         0.014881
# oty_annual_avg_wkly_wage_pct_chg -0.057409 -0.081731         0.037928
# oty_avg_annual_pay_pct_chg       -0.057666 -0.081808         0.037887
#
#                                      asian   poverty     owned  occupied  \
# target                            0.216522 -0.104923 -0.069584 -0.030849
# bachelors_degree                  0.499943 -0.560311 -0.213299  0.259046
# gini_index                        0.068336  0.524108 -0.500854 -0.176396
# median_household_income           0.487920 -0.823738  0.157731  0.366485
# median_age                       -0.229219 -0.154721  0.518069 -0.435612
# white                            -0.312414 -0.416659  0.533854 -0.026406
# black                            -0.047877  0.476322 -0.363955 -0.045915
# native_american                  -0.027763  0.119649 -0.009947 -0.120978
# asian                             1.000000 -0.264372 -0.339130  0.236704
# poverty                          -0.264372  1.000000 -0.361877 -0.264666
# owned                            -0.339130 -0.361877  1.000000 -0.182267
# occupied                          0.236704 -0.264666 -0.182267  1.000000
# avg_annual_pay                    0.589766 -0.395042 -0.376190  0.361296
# oty_annual_avg_estabs_pct_chg     0.194349 -0.151626 -0.082150  0.073441
# oty_annual_avg_emplvl_pct_chg     0.378897 -0.190335 -0.221837  0.186082
# oty_total_annual_wages_pct_chg   -0.001161 -0.016968  0.014420 -0.002246
# oty_taxable_annual_wages_pct_chg  0.346116 -0.190044 -0.189627  0.182034
# oty_annual_contributions_pct_chg  0.052261 -0.029170 -0.002057  0.054314
# oty_annual_avg_wkly_wage_pct_chg  0.283112 -0.168423 -0.227923  0.178779
# oty_avg_annual_pay_pct_chg        0.283805 -0.168904 -0.228598  0.179172
#
#                                   avg_annual_pay  \
# target                                  0.315393
# bachelors_degree                        0.734697
# gini_index                              0.230965
# median_household_income                 0.594860
# median_age                             -0.251313
# white                                  -0.210107
# black                                  -0.008918
# native_american                        -0.089292
# asian                                   0.589766
# poverty                                -0.395042
# owned                                  -0.376190
# occupied                                0.361296
# avg_annual_pay                          1.000000
# oty_annual_avg_estabs_pct_chg           0.180851
# oty_annual_avg_emplvl_pct_chg           0.441182
# oty_total_annual_wages_pct_chg         -0.004584
# oty_taxable_annual_wages_pct_chg        0.421950
# oty_annual_contributions_pct_chg        0.119655
# oty_annual_avg_wkly_wage_pct_chg        0.449632
# oty_avg_annual_pay_pct_chg              0.451019
#
#                                   oty_annual_avg_estabs_pct_chg  \
# target                                                 0.258652
# bachelors_degree                                       0.180920
# gini_index                                            -0.039679
# median_household_income                                0.227542
# median_age                                            -0.137195
# white                                                 -0.061287
# black                                                 -0.073566
# native_american                                        0.084328
# asian                                                  0.194349
# poverty                                               -0.151626
# owned                                                 -0.082150
# occupied                                               0.073441
# avg_annual_pay                                         0.180851
# oty_annual_avg_estabs_pct_chg                          1.000000
# oty_annual_avg_emplvl_pct_chg                          0.334208
# oty_total_annual_wages_pct_chg                        -0.002006
# oty_taxable_annual_wages_pct_chg                       0.248432
# oty_annual_contributions_pct_chg                      -0.065190
# oty_annual_avg_wkly_wage_pct_chg                       0.102173
# oty_avg_annual_pay_pct_chg                             0.102527
#
#                                   oty_annual_avg_emplvl_pct_chg  \
# target                                                 0.226192
# bachelors_degree                                       0.350610
# gini_index                                             0.068833
# median_household_income                                0.305074
# median_age                                            -0.204404
# white                                                 -0.137719
# black                                                 -0.045334
# native_american                                        0.040492
# asian                                                  0.378897
# poverty                                               -0.190335
# owned                                                 -0.221837
# occupied                                               0.186082
# avg_annual_pay                                         0.441182
# oty_annual_avg_estabs_pct_chg                          0.334208
# oty_annual_avg_emplvl_pct_chg                          1.000000
# oty_total_annual_wages_pct_chg                         0.029077
# oty_taxable_annual_wages_pct_chg                       0.713485
# oty_annual_contributions_pct_chg                       0.300115
# oty_annual_avg_wkly_wage_pct_chg                       0.301378
# oty_avg_annual_pay_pct_chg                             0.302402
#
#                                   oty_total_annual_wages_pct_chg  \
# target                                                  0.019612
# bachelors_degree                                       -0.027709
# gini_index                                             -0.049542
# median_household_income                                 0.019408
# median_age                                             -0.013681
# white                                                  -0.020908
# black                                                   0.027787
# native_american                                        -0.005250
# asian                                                  -0.001161
# poverty                                                -0.016968
# owned                                                   0.014420
# occupied                                               -0.002246
# avg_annual_pay                                         -0.004584
# oty_annual_avg_estabs_pct_chg                          -0.002006
# oty_annual_avg_emplvl_pct_chg                           0.029077
# oty_total_annual_wages_pct_chg                          1.000000
# oty_taxable_annual_wages_pct_chg                        0.031034
# oty_annual_contributions_pct_chg                        0.006439
# oty_annual_avg_wkly_wage_pct_chg                        0.025568
# oty_avg_annual_pay_pct_chg                              0.025416
#
#                                   oty_taxable_annual_wages_pct_chg  \
# target                                                    0.161088
# bachelors_degree                                          0.323984
# gini_index                                                0.061314
# median_household_income                                   0.284913
# median_age                                               -0.170968
# white                                                    -0.112502
# black                                                    -0.039552
# native_american                                           0.005013
# asian                                                     0.346116
# poverty                                                  -0.190044
# owned                                                    -0.189627
# occupied                                                  0.182034
# avg_annual_pay                                            0.421950
# oty_annual_avg_estabs_pct_chg                             0.248432
# oty_annual_avg_emplvl_pct_chg                             0.713485
# oty_total_annual_wages_pct_chg                            0.031034
# oty_taxable_annual_wages_pct_chg                          1.000000
# oty_annual_contributions_pct_chg                          0.457207
# oty_annual_avg_wkly_wage_pct_chg                          0.338136
# oty_avg_annual_pay_pct_chg                                0.339378
#
#                                   oty_annual_contributions_pct_chg  \
# target                                                    0.034840
# bachelors_degree                                          0.029450
# gini_index                                                0.033912
# median_household_income                                   0.052690
# median_age                                               -0.037600
# white                                                    -0.033815
# black                                                     0.015284
# native_american                                           0.014881
# asian                                                     0.052261
# poverty                                                  -0.029170
# owned                                                    -0.002057
# occupied                                                  0.054314
# avg_annual_pay                                            0.119655
# oty_annual_avg_estabs_pct_chg                            -0.065190
# oty_annual_avg_emplvl_pct_chg                             0.300115
# oty_total_annual_wages_pct_chg                            0.006439
# oty_taxable_annual_wages_pct_chg                          0.457207
# oty_annual_contributions_pct_chg                          1.000000
# oty_annual_avg_wkly_wage_pct_chg                          0.077226
# oty_avg_annual_pay_pct_chg                                0.077618
#
#                                   oty_annual_avg_wkly_wage_pct_chg  \
# target                                                    0.136636
# bachelors_degree                                          0.332476
# gini_index                                                0.109845
# median_household_income                                   0.238399
# median_age                                               -0.172279
# white                                                    -0.057409
# black                                                    -0.081731
# native_american                                           0.037928
# asian                                                     0.283112
# poverty                                                  -0.168423
# owned                                                    -0.227923
# occupied                                                  0.178779
# avg_annual_pay                                            0.449632
# oty_annual_avg_estabs_pct_chg                             0.102173
# oty_annual_avg_emplvl_pct_chg                             0.301378
# oty_total_annual_wages_pct_chg                            0.025568
# oty_taxable_annual_wages_pct_chg                          0.338136
# oty_annual_contributions_pct_chg                          0.077226
# oty_annual_avg_wkly_wage_pct_chg                          1.000000
# oty_avg_annual_pay_pct_chg                                0.999988
#
#                                   oty_avg_annual_pay_pct_chg
# target                                              0.137004
# bachelors_degree                                    0.333453
# gini_index                                          0.110247
# median_household_income                             0.239099
# median_age                                         -0.172526
# white                                              -0.057666
# black                                              -0.081808
# native_american                                     0.037887
# asian                                               0.283805
# poverty                                            -0.168904
# owned                                              -0.228598
# occupied                                            0.179172
# avg_annual_pay                                      0.451019
# oty_annual_avg_estabs_pct_chg                       0.102527
# oty_annual_avg_emplvl_pct_chg                       0.302402
# oty_total_annual_wages_pct_chg                      0.025416
# oty_taxable_annual_wages_pct_chg                    0.339378
# oty_annual_contributions_pct_chg                    0.077618
# oty_annual_avg_wkly_wage_pct_chg                    0.999988
# oty_avg_annual_pay_pct_chg                          1.000000

# %% [markdown]
# # Linear Regression

# %%
linreg = LinearRegression()
linreg.fit(X_train,T_train)
linreg.score(X_train,T_train)
# Out:
# 0.3308548799576224

# %%
Y_train = linreg.predict(X_train)
rmse_train = np.sqrt(np.mean((Y_train-T_train)**2))
print(f"Train RMSE: {rmse_train}")

Y_test = linreg.predict(X_test)
rmse_test = np.sqrt(np.mean((Y_test-T_test)**2))
print(f"Test RMSE: {rmse_test}")
# Out:
# Train RMSE: 0.10285913685940133
# Test RMSE: 0.1167305379436932

# %%
plt.figure(figsize=(15,15))
plt.plot(T_test[:], label="crash actual")
plt.plot(Y_test[:], label="crash pred")
plt.legend()

# %% [markdown]
# Its really bad at extreme values.

# %%
pd.DataFrame(linreg.coef_, columns=labels)
# Out:
#    bachelors_degree  gini_index  median_household_income  median_age  \
# 0         -0.394724    0.056781                 0.300952   -0.039757
#
#       white     black  native_american    asian   poverty     owned  occupied  \
# 0 -0.437488 -0.346547        -0.313609 -0.36461 -0.039186  0.045864 -0.223701
#
#    avg_annual_pay  oty_annual_avg_estabs_pct_chg  \
# 0        0.422188                       0.231597
#
#    oty_annual_avg_emplvl_pct_chg  oty_total_annual_wages_pct_chg  \
# 0                       0.177879                       -0.019857
#
#    oty_taxable_annual_wages_pct_chg  oty_annual_contributions_pct_chg  \
# 0                         -0.310809                          0.148418
#
#    oty_annual_avg_wkly_wage_pct_chg  oty_avg_annual_pay_pct_chg
# 0                         24.672299                  -24.584518

# %% [markdown]
# # Get predictions for 2020

# %%
to_predict_df = pd.read_csv('../data/now.csv')
to_predict_df = to_predict_df.loc[to_predict_df['GISJOIN'] != 'GISJOIN',:]

X_to_predict = to_predict_df[labels].values.astype(np.float32)
print(X_to_predict.shape)
min_max_scaler_pred = MinMaxScaler()
min_max_scaler_pred.fit(X_to_predict)
X_to_predict = min_max_scaler.transform(X_to_predict)

results = linreg.predict(X_to_predict)

# now write results

to_predict_df["crash_amount"] = results

to_predict_df

import json

with open('../frontend/data.json') as f:
    shape_data = json.load(f)
    
to_write = []

old_features = shape_data['features'] if not isinstance(shape_data, list) else shape_data

for old_feature in old_features:
    gisjoin = old_feature['properties']['GISJOIN']
    result = to_predict_df.loc[to_predict_df['GISJOIN'] == gisjoin].T.to_dict()
    if not len(list(result.keys())):
        continue
    result = result[list(result.keys())[0]]
    if 0 > result['crash_amount'] or result['crash_amount'] > 1:
        continue
    old_feature['properties'] = {**old_feature['properties'], **result}
    to_write.append(old_feature)

with open('../frontend/data.json', 'w') as jsonfile:
    json.dump(to_write, jsonfile)
# Out:
# (3219, 19)

# %% [markdown]
# # Where got worse?

# %%
sig = []
for index, pred_2007_row in new_data_df.iterrows():
    gisjoin = pred_2007_row['GISJOIN']
    crash_amount_old = pred_2007_row['crash_amount']
    pred_2020_row = to_predict_df.loc[to_predict_df['GISJOIN'] == gisjoin]
    if not len(list(pred_2020_row.keys())):
        continue
    crash_amount_new = pred_2020_row['crash_amount'].values[0]
    difference = crash_amount_new - crash_amount_old
    if difference > 0.2:
        siga = [pred_2007_row['GISJOIN'], pred_2007_row['county_name'], crash_amount_old, crash_amount_new]
        sig.append(siga)


more_risk_df = pd.DataFrame(sig, columns=["GISJOIN", "County Name", "Old Crash Amount", "New Crash Amount"])
more_risk_df
# Out:
#      GISJOIN         County Name  Old Crash Amount  New Crash Amount
# 0   G0600370  Los Angeles County          0.378148          0.598548
# 1   G4802010       Harris County          0.119461          0.533644
# 2   G4801130       Dallas County          0.162000          0.501975
# 3   G4804390      Tarrant County          0.115052          0.409578
# 4   G0600850  Santa Clara County          0.306029          0.512989
# ..       ...                 ...               ...               ...
# 57  G5101190    Middlesex County          0.106166          0.313387
# 58  G2101870         Owen County          0.066577          0.269779
# 59  G2500190    Nantucket County          0.106534          0.414681
# 60  G3600410     Hamilton County          0.070345          0.396248
# 61  G1302390      Quitman County          0.224699          1.410164
#
# [62 rows x 4 columns]

# %%
with open('../frontend/data.json') as f:
    shape_data = json.load(f)
    
to_write = []

old_features = shape_data['features'] if not isinstance(shape_data, list) else shape_data

for old_feature in old_features:
    gisjoin = old_feature['properties']['GISJOIN']
    result = more_risk_df.loc[more_risk_df['GISJOIN'] == gisjoin].T.to_dict()
    if not len(list(result.keys())):
        continue
    result = result[list(result.keys())[0]]
    if 0 > result['New Crash Amount'] or result['New Crash Amount'] > 1:
        continue
    old_feature['properties'] = result
    to_write.append(old_feature)

with open('../frontend/extremes.json', 'w') as jsonfile:
    json.dump(to_write, jsonfile)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [29], in <module>
#       1 with open('../frontend/data.json') as f:
# ----> 2     shape_data = json.load(f)
#       4 to_write = []
#       6 old_features = shape_data['features'] if not isinstance(shape_data, list) else shape_data
#
# File /usr/local/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /usr/local/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/local/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/local/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Make a differences data file

# %%
sig = []
for index, pred_2007_row in new_data_df.iterrows():
    gisjoin = pred_2007_row['GISJOIN']
    crash_amount_old = pred_2007_row['crash_amount']
    pred_2020_row = to_predict_df.loc[to_predict_df['GISJOIN'] == gisjoin]
    if not len(list(pred_2020_row.keys())):
        continue
    crash_amount_new = pred_2020_row['crash_amount'].values[0]
    difference = crash_amount_new - crash_amount_old
    siga = [pred_2007_row['GISJOIN'], pred_2007_row['county_name'], crash_amount_old, crash_amount_new, difference]
    sig.append(siga)


difference_df = pd.DataFrame(sig, columns=["GISJOIN", "County Name", "Old Crash Amount", "New Crash Amount", "Difference"])
difference_df
# Out:
#        GISJOIN         County Name  Old Crash Amount  New Crash Amount  \
# 0     G0600370  Los Angeles County          0.378148          0.598548
# 1     G1700310         Cook County          0.413657          0.520363
# 2     G4802010       Harris County          0.119461          0.533644
# 3     G0400130     Maricopa County          0.560487          0.428296
# 4     G0600730    San Diego County          0.383084          0.429878
# ...        ...                 ...               ...               ...
# 1061  G4000450        Ellis County          0.215735          0.182496
# 1062  G1301010       Echols County          0.242985         -0.086818
# 1063  G1303070      Webster County          0.249534          0.324272
# 1064  G1302390      Quitman County          0.224699          1.410164
# 1065  G1302650   Taliaferro County          0.210249          0.334357
#
#       Difference
# 0       0.220400
# 1       0.106706
# 2       0.414183
# 3      -0.132190
# 4       0.046794
# ...          ...
# 1061   -0.033239
# 1062   -0.329802
# 1063    0.074738
# 1064    1.185465
# 1065    0.124108
#
# [1066 rows x 5 columns]

# %%
with open('../frontend/data.json') as f:
    shape_data = json.load(f)
    
to_write = []

old_features = shape_data['features'] if not isinstance(shape_data, list) else shape_data

for old_feature in old_features:
    gisjoin = old_feature['properties']['GISJOIN']
    result = difference_df.loc[difference_df['GISJOIN'] == gisjoin].T.to_dict()
    if not len(list(result.keys())):
        continue
    result = result[list(result.keys())[0]]
    if 0 > result['New Crash Amount'] or result['New Crash Amount'] > 1:
        continue
    old_feature['properties'] = result
    to_write.append(old_feature)

# print(len(old_features))
with open('../frontend/differences.json', 'w') as jsonfile:
    json.dump(to_write, jsonfile)

# %% [markdown]
# # Deep Learning

# %% [markdown]
# Let's just try deep learning for fun.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2022-04-27 11:30:49.046975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu", name="layer1"),
        layers.Dense(256, activation="relu", name="layer2"),
        layers.Dense(64, activation="relu", name="layer3"),
        layers.Dense(1, name='out', activation='sigmoid')
    ]
)
#model.summary()
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mean_squared_error', optimizer=opt)

# %%
n_epochs = 250
history1 = model.fit(X_train, T_train, batch_size=16, epochs=n_epochs, verbose=1, validation_data=(X_test,T_test))
# Out:
# 2022-04-27 11:31:39.673849: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-27 11:31:39.708621: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2593770000 Hz
# Epoch 1/250
# 47/47 [==============================] - 1s 7ms/step - loss: 0.0240 - val_loss: 0.0155
# Epoch 2/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0118
# Epoch 3/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 4/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0126
# Epoch 5/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0123
# Epoch 6/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0146
# Epoch 7/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 8/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0110
# Epoch 9/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0110
# Epoch 10/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0110
# Epoch 11/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 12/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0105
# Epoch 13/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0100
# Epoch 14/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0120
# Epoch 15/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 16/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0111
# Epoch 17/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0100
# Epoch 18/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0150
# Epoch 19/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0097
# Epoch 20/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 21/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 22/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 23/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0115
# Epoch 24/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 25/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 26/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0100
# Epoch 27/250
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0123
# Epoch 28/250
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 29/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0110
# Epoch 30/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0107
# Epoch 31/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0110
# Epoch 32/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0106
# Epoch 33/250
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0082 - val_loss: 0.0105
# Epoch 34/250
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0084 - val_loss: 0.0113
# Epoch 35/250
# 47/47 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0101
# Epoch 36/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0100
# Epoch 37/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0115
# Epoch 38/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 39/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0102
# Epoch 40/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0103
# Epoch 41/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0116
# Epoch 42/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0095
# Epoch 43/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 44/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0104
# Epoch 45/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0101
# Epoch 46/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0102
# Epoch 47/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0094
# Epoch 48/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0099
# Epoch 49/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0104
# Epoch 50/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 51/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0105
# Epoch 52/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0098
# Epoch 53/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 54/250
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0102
# Epoch 55/250
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0108
# Epoch 56/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0103
# Epoch 57/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0099
# Epoch 58/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0096
# Epoch 59/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0097
# Epoch 60/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0096
# Epoch 61/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0101
# Epoch 62/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0095
# Epoch 63/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0094
# Epoch 64/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0099
# Epoch 65/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0098
# Epoch 66/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0097
# Epoch 67/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0101
# Epoch 68/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0101
# Epoch 69/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0102
# Epoch 70/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0098
# Epoch 71/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0101
# Epoch 72/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0110
# Epoch 73/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0101
# Epoch 74/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0099
# Epoch 75/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0097
# Epoch 76/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0098
# Epoch 77/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 78/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0100
# Epoch 79/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0098
# Epoch 80/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0099
# Epoch 81/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 82/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0104
# Epoch 83/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 84/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0095
# Epoch 85/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 86/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0107
# Epoch 87/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0100
# Epoch 88/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0097
# Epoch 89/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0099
# Epoch 90/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0096
# Epoch 91/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0105
# Epoch 92/250
# 47/47 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0098
# Epoch 93/250
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 94/250
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0096
# Epoch 95/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0101
# Epoch 96/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0100
# Epoch 97/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0110
# Epoch 98/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 99/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0096
# Epoch 100/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 101/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0103
# Epoch 102/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0098
# Epoch 103/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0097
# Epoch 104/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0097
# Epoch 105/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 106/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0096
# Epoch 107/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 108/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0101
# Epoch 109/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 110/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0098
# Epoch 111/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 112/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0111
# Epoch 113/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 114/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0093
# Epoch 115/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0096
# Epoch 116/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0096
# Epoch 117/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 118/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0097
# Epoch 119/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0098
# Epoch 120/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0095
# Epoch 121/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0094
# Epoch 122/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0096
# Epoch 123/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0095
# Epoch 124/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 125/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0110
# Epoch 126/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0112
# Epoch 127/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0097
# Epoch 128/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0097
# Epoch 129/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0098
# Epoch 130/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0100
# Epoch 131/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0100
# Epoch 132/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0095
# Epoch 133/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0096
# Epoch 134/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0100
# Epoch 135/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0096
# Epoch 136/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0101
# Epoch 137/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0102
# Epoch 138/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0092
# Epoch 139/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 140/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0101
# Epoch 141/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0095
# Epoch 142/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0106
# Epoch 143/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0103
# Epoch 144/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0093
# Epoch 145/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0098
# Epoch 146/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0093
# Epoch 147/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0096
# Epoch 148/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0094
# Epoch 149/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0094
# Epoch 150/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0094
# Epoch 151/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0102
# Epoch 152/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0092
# Epoch 153/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0101
# Epoch 154/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0099
# Epoch 155/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0095
# Epoch 156/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0097
# Epoch 157/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0098
# Epoch 158/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0094
# Epoch 159/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0100
# Epoch 160/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0103
# Epoch 161/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0094
# Epoch 162/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0093
# Epoch 163/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0091
# Epoch 164/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0099
# Epoch 165/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0103
# Epoch 166/250
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0103
# Epoch 167/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0094
# Epoch 168/250
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0107
# Epoch 169/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0093
# Epoch 170/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0101
# Epoch 171/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 172/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0094
# Epoch 173/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0093
# Epoch 174/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0096
# Epoch 175/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0096
# Epoch 176/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0090
# Epoch 177/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0094
# Epoch 178/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0109
# Epoch 179/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0095
# Epoch 180/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0101
# Epoch 181/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0096
# Epoch 182/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0095
# Epoch 183/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0096
# Epoch 184/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0094
# Epoch 185/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0101
# Epoch 186/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0098
# Epoch 187/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0102
# Epoch 188/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0099
# Epoch 189/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0109
# Epoch 190/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0096
# Epoch 191/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0103
# Epoch 192/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0103
# Epoch 193/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0107
# Epoch 194/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0100
# Epoch 195/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0101
# Epoch 196/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0102
# Epoch 197/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 198/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0099
# Epoch 199/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0103
# Epoch 200/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0114
# Epoch 201/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0097
# Epoch 202/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0115
# Epoch 203/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0100
# Epoch 204/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0103
# Epoch 205/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0105
# Epoch 206/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 207/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0098
# Epoch 208/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0106
# Epoch 209/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0098
# Epoch 210/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0099
# Epoch 211/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0103
# Epoch 212/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0108
# Epoch 213/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0102
# Epoch 214/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0108
# Epoch 215/250
# 47/47 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0100
# Epoch 216/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0096
# Epoch 217/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0107
# Epoch 218/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0111
# Epoch 219/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0099
# Epoch 220/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0104
# Epoch 221/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0101
# Epoch 222/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0100
# Epoch 223/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0099
# Epoch 224/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0101
# Epoch 225/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0098
# Epoch 226/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0110
# Epoch 227/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0102
# Epoch 228/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0103
# Epoch 229/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0112
# Epoch 230/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0099
# Epoch 231/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0110
# Epoch 232/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0104
# Epoch 233/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0114
# Epoch 234/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0115
# Epoch 235/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0103
# Epoch 236/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0105
# Epoch 237/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0111
# Epoch 238/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0102
# Epoch 239/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0101
# Epoch 240/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0106
# Epoch 241/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0121
# Epoch 242/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0103
# Epoch 243/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0105
# Epoch 244/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0109
# Epoch 245/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 246/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 247/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0110
# Epoch 248/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0109
# Epoch 249/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0111
# Epoch 250/250
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0111

# %%
Y_train = model.predict(X_train)
Y_test = model.predict(X_test)

# %%
Y_train = linreg.predict(X_train)
rmse_train = np.sqrt(np.mean((Y_train-T_train)**2))
print(f"Train RMSE: {rmse_train}")

Y_test = linreg.predict(X_test)
rmse_test = np.sqrt(np.mean((Y_test-T_test)**2))
print(f"Test RMSE: {rmse_test}")
# Out:
# Train RMSE: 0.10577884336132523
# Test RMSE: 0.10856791460266536

# %%
plt.figure(figsize=(15,15))

num_ex = 50
plt.plot(T_test[:num_ex])
plt.plot(Y_test[:num_ex]);

# %% [markdown]
# Not better enough
